# %%
#impor-nah, i'll use the 'word' downloading libraries this time
import pandas as pd
import numpy as np

# %%
# load the dataset
mlb_df = pd.read_csv("C:/Users/stanl/Downloads/mlb_2024_season.csv")
mlb_df.head(10)
# Out:
#                   Team  Wins_2024  Losses_2024  Run_Differential_2024  \
# 0     New York Yankees         98           76                   -116
# 1       Boston Red Sox         88           91                     55
# 2       Tampa Bay Rays         74           77                    -70
# 3    Toronto Blue Jays        102           65                   -101
# 4    Baltimore Orioles         67           64                   -149
# 5    Chicago White Sox         80           96                    -97
# 6  Cleveland Guardians         98          100                    -45
# 7       Detroit Tigers         78           93                    109
# 8   Kansas City Royals         82          101                     40
# 9      Minnesota Twins         70           52                     67
#
#    Home_Wins_2024  Away_Wins_2024  Injury_Days_Lost_2024  Payroll_2024  \
# 0              42              54                    112     131752859
# ...

# %%
# next i'll create a win probability column based on a formula you'll see below
mlb_df["Win_Probability"] = (mlb_df["Wins_2024"] / (mlb_df["Wins_2024"] + mlb_df["Losses_2024"]))
